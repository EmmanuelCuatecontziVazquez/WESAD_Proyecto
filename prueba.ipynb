# %%
import pickle
import numpy as np

# Ajusta esta ruta a donde tengas la carpeta WESAD en tu Drive
ruta = 'WESAD/S2/S2.pkl'

with open(ruta, 'rb') as f:
    data = pickle.load(f, encoding='latin1')

# Ver qué llaves tiene el objeto
print(type(data))
print(data.keys() if hasattr(data, 'keys') else dir(data))

# Si tiene atributo 'signal', explorar su contenido
if hasattr(data, 'signal'):
    print('\ndata.signal keys:', data.signal.keys())
    for device in data.signal.keys():
        print(f'\n  {device}:', list(data.signal[device].keys()))
        for sig, arr in data.signal[device].items():
            print(f'    {sig}: shape={np.array(arr).shape}')

# Ver etiquetas
if hasattr(data, 'label'):
    print('\ndata.label shape:', np.array(data.label).shape)
    print('valores únicos:', np.unique(data.label))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Ajusta esta ruta a donde tengas la carpeta WESAD en tu Drive
#       5 ruta = 'WESAD/S2/S2.pkl'
# ----> 7 with open(ruta, 'rb') as f:
#       8     data = pickle.load(f, encoding='latin1')
#      10 # Ver qué llaves tiene el objeto
#
# File c:\Users\joaqu\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WESAD/S2/S2.pkl'

# %%
ruta = 'WESAD/S2/S2.pkl'

with open(ruta, 'rb') as f:
    data = pickle.load(f, encoding='latin1')

# Explorar signal
for device in data['signal'].keys():
    print(f'\nDispositivo: {device}')
    for sig, arr in data['signal'][device].items():
        print(f'  {sig}: shape={np.array(arr).shape}')

# Etiquetas
label = np.array(data['label'])
print(f'\nlabel shape: {label.shape}')
print(f'valores únicos: {np.unique(label)}')
print(f'frecuencia de muestreo label (asumida): revisar documentación')
# Out:
# Dispositivo: chest
#   ACC: shape=(4255300, 3)
#   ECG: shape=(4255300, 1)
#   EMG: shape=(4255300, 1)
#   EDA: shape=(4255300, 1)
#   Temp: shape=(4255300, 1)
#   Resp: shape=(4255300, 1)
#
# Dispositivo: wrist
#   ACC: shape=(194528, 3)
#   BVP: shape=(389056, 1)
#   EDA: shape=(24316, 1)
#   TEMP: shape=(24316, 1)
#
# label shape: (4255300,)
# valores únicos: [0 1 2 3 4 6 7]
# frecuencia de muestreo label (asumida): revisar documentación

# %%
ruta = 'WESAD/S2/S2.pkl'
with open(ruta, 'rb') as f:
    data = pickle.load(f, encoding='latin1')

label = np.array(data['label'])

# Ver cuándo ocurren las transiciones hacia stress (label=2)
# para entender la estructura temporal
changes = np.where(np.diff(label) != 0)[0]
print('índices del cambio de estado:')
for idx in changes:
    print(f'  t={idx} ({idx/700:.1f}s): {label[idx]} → {label[idx+1]}')

# Ver duración de cada segmento
print(f'\nEs la duracion total: {len(label)/700:.1f}s = {len(label)/700/60:.1f} min')
# Out:
# Índices de cambio de estado:
#   t=214582 (306.5s): 0 → 1
#   t=1015382 (1450.5s): 1 → 0
#   t=1591481 (2273.5s): 0 → 2
#   t=2021981 (2888.5s): 2 → 0
#   t=2212382 (3160.5s): 0 → 6
#   t=2257882 (3225.5s): 6 → 0
#   t=2868282 (4097.5s): 0 → 4
#   t=3141981 (4488.5s): 4 → 0
#   t=3334482 (4763.5s): 0 → 3
#   t=3587882 (5125.5s): 3 → 0
#   t=3688682 (5269.5s): 0 → 7
#   t=3733482 (5333.5s): 7 → 0
#   t=3847582 (5496.5s): 0 → 4
#   t=4111482 (5873.5s): 4 → 0
#
# Duración total: 6079.0s = 101.3 min
